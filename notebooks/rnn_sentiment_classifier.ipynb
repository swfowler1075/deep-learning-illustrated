# %% [markdown]
# # RNN Sentiment Classifier

# %% [markdown]
# In this notebook, we use an RNN to classify IMDB movie reviews by their sentiment.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/the-deep-learners/deep-learning-illustrated/blob/master/notebooks/rnn_sentiment_classifier.ipynb)

# %% [markdown]
# #### Load dependencies

# %%
import keras
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, SpatialDropout1D
from keras.layers import SimpleRNN # new!
from keras.callbacks import ModelCheckpoint
import os
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Set hyperparameters

# %%
# output directory name:
output_dir = 'model_output/rnn'

# training:
epochs = 16 # way more!
batch_size = 128

# vector-space embedding:
n_dim = 64
n_unique_words = 10000
max_review_length = 100 # lowered due to vanishing gradient over time
pad_type = trunc_type = 'pre'
drop_embed = 0.2

# RNN layer architecture:
n_rnn = 256
drop_rnn = 0.2

# dense layer architecture:
# n_dense = 256
# dropout = 0.2

# %% [markdown]
# #### Load data

# %%
(x_train, y_train), (x_valid, y_valid) = imdb.load_data(num_words=n_unique_words) # removed n_words_to_skip
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# #### Preprocess data

# %%
x_train = pad_sequences(x_train, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value=0)
x_valid = pad_sequences(x_valid, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value=0)

# %% [markdown]
# #### Design neural network architecture

# %%
model = Sequential()
model.add(Embedding(n_unique_words, n_dim, input_length=max_review_length))
model.add(SpatialDropout1D(drop_embed))
model.add(SimpleRNN(n_rnn, dropout=drop_rnn))
# model.add(Dense(n_dense, activation='relu')) # typically don't see top dense layer in NLP like in
# model.add(Dropout(dropout))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d               │ ?                      │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Configure model

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
modelcheckpoint = ModelCheckpoint(filepath=output_dir+"/weights.{epoch:02d}.keras")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# #### Train!

# %%
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_valid, y_valid), callbacks=[modelcheckpoint])
# Out:
# Epoch 1/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 69s 335ms/step - accuracy: 0.5376 - loss: 0.6852 - val_accuracy: 0.5985 - val_loss: 0.6482
# Epoch 2/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 65s 333ms/step - accuracy: 0.6589 - loss: 0.6073 - val_accuracy: 0.6004 - val_loss: 0.6581
# Epoch 3/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 87s 357ms/step - accuracy: 0.7330 - loss: 0.5258 - val_accuracy: 0.6368 - val_loss: 0.6504
# Epoch 4/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 76s 325ms/step - accuracy: 0.7977 - loss: 0.4289 - val_accuracy: 0.5944 - val_loss: 0.6626
# Epoch 5/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 80s 317ms/step - accuracy: 0.7160 - loss: 0.5586 - val_accuracy: 0.6310 - val_loss: 0.6515
# Epoch 6/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 324ms/step - accuracy: 0.7452 - loss: 0.5068 - val_accuracy: 0.6684 - val_loss: 0.6260
# Epoch 7/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 81s 320ms/step - accuracy: 0.8090 - loss: 0.4183 - val_accuracy: 0.7190 - val_loss: 0.5697
# Epoch 8/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 324ms/step - accuracy: 0.8493 - loss: 0.3500 - val_accuracy: 0.7793 - val_loss: 0.4925
# Epoch 9/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 82s 324ms/step - accuracy: 0.8892 - loss: 0.2723 - val_accuracy: 0.7910 - val_loss: 0.4787
# Epoch 10/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 64s 326ms/step - accuracy: 0.9084 - loss: 0.2308 - val_accuracy: 0.8062 - val_loss: 0.4920
# Epoch 11/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 62s 317ms/step - accuracy: 0.9195 - loss: 0.2081 - val_accuracy: 0.8109 - val_loss: 0.5395
# Epoch 12/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 321ms/step - accuracy: 0.9228 - loss: 0.1948 - val_accuracy: 0.7992 - val_loss: 0.5533
# Epoch 13/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 323ms/step - accuracy: 0.9356 - loss: 0.1680 - val_accuracy: 0.8026 - val_loss: 0.6036
# Epoch 14/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 62s 318ms/step - accuracy: 0.9219 - loss: 0.1930 - val_accuracy: 0.7622 - val_loss: 0.6448
# Epoch 15/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 320ms/step - accuracy: 0.9360 - loss: 0.1682 - val_accuracy: 0.7584 - val_loss: 0.6459
# Epoch 16/16
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 64s 325ms/step - accuracy: 0.9499 - loss: 0.1309 - val_accuracy: 0.8032 - val_loss: 0.6494

# %% [markdown]
# #### Evaluate

# %%
model.load_weights(output_dir+"/weights.07.keras")

# %%
y_hat = model.predict(x_valid)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 36ms/step

# %%
plt.hist(y_hat)
_ = plt.axvline(x=0.5, color='orange')

# %%
"{:0.2f}".format(roc_auc_score(y_valid, y_hat)*100.0)
# Out:
# '79.56'
